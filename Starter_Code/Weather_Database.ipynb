# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dd4489015a0d53691a4504c482fe26b5

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | vila franca do campo
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | carnot
# Processing Record 10 of Set 1 | caborca
# Processing Record 11 of Set 1 | biloela
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | port blair
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | marsh harbour
# Processing Record 20 of Set 1 | tongchuan
# Processing Record 21 of Set 1 | izumo
# Processing Record 22 of Set 1 | beian
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | yerbogachen
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | shelburne
# Processing Record 29 of Set 1 | praia da vitoria
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | tagab
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | port hedland
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | ladario
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | mareeba
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | mahajanga
# Processing Record 50 of Set 1 | pleasanton
# Processing Record 1 of Set 2 | atar
# Processing Record 2 of Set 2 | xai-xai
# Processing Record 3 of Set 2 | seoni malwa
# Processing Record 4 of Set 2 | jiexiu
# Processing Record 5 of Set 2 | virginia beach
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | zeya
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | san vicente
# Processing Record 14 of Set 2 | linxia
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | zlatica
# Processing Record 17 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | alekseyevka
# Processing Record 24 of Set 2 | challapata
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | torbay
# Processing Record 27 of Set 2 | tezu
# Processing Record 28 of Set 2 | upington
# Processing Record 29 of Set 2 | sabzevar
# Processing Record 30 of Set 2 | shingu
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | koygorodok
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | luena
# Processing Record 36 of Set 2 | banda aceh
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | bara
# Processing Record 39 of Set 2 | mbumi
# Processing Record 40 of Set 2 | katha
# City not found. Skipping...
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | novikovo
# Processing Record 43 of Set 2 | kisangani
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | quatre cocos
# Processing Record 48 of Set 2 | kavieng
# Processing Record 49 of Set 2 | fulitun
# City not found. Skipping...
# Processing Record 50 of Set 2 | preeceville
# Processing Record 1 of Set 3 | staryy nadym
# Processing Record 2 of Set 3 | leningradskiy
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | mehamn
# Processing Record 5 of Set 3 | homer
# Processing Record 6 of Set 3 | palmer
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | jalu
# Processing Record 13 of Set 3 | grindavik
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | syracuse
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | nishihara
# Processing Record 21 of Set 3 | parabel
# Processing Record 22 of Set 3 | kiunga
# Processing Record 23 of Set 3 | gobabis
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | halifax
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | taksimo
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | komsomolskiy
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | biak
# Processing Record 35 of Set 3 | mazagao
# Processing Record 36 of Set 3 | morondava
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | manokwari
# Processing Record 42 of Set 3 | new norfolk
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | sapa
# Processing Record 45 of Set 3 | arman
# Processing Record 46 of Set 3 | krasnoselkup
# Processing Record 47 of Set 3 | piacabucu
# Processing Record 48 of Set 3 | cifuentes
# Processing Record 49 of Set 3 | durban
# Processing Record 50 of Set 3 | yulara
# Processing Record 1 of Set 4 | abha
# Processing Record 2 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 3 of Set 4 | mayo
# Processing Record 4 of Set 4 | glenwood springs
# Processing Record 5 of Set 4 | potosi
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | kaseda
# Processing Record 8 of Set 4 | leh
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | burgeo
# Processing Record 11 of Set 4 | vardo
# Processing Record 12 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 13 of Set 4 | yar-sale
# Processing Record 14 of Set 4 | rocha
# Processing Record 15 of Set 4 | washougal
# Processing Record 16 of Set 4 | torrington
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | karpogory
# Processing Record 21 of Set 4 | ambilobe
# Processing Record 22 of Set 4 | kyabe
# Processing Record 23 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 4 | tilichiki
# Processing Record 25 of Set 4 | mecca
# Processing Record 26 of Set 4 | erzincan
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | jasper
# Processing Record 30 of Set 4 | general pico
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | dalianwan
# Processing Record 33 of Set 4 | lafia
# Processing Record 34 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 4 | dhidhdhoo
# Processing Record 36 of Set 4 | meadville
# Processing Record 37 of Set 4 | baykit
# Processing Record 38 of Set 4 | maholi
# Processing Record 39 of Set 4 | taoudenni
# Processing Record 40 of Set 4 | thyolo
# Processing Record 41 of Set 4 | celestun
# Processing Record 42 of Set 4 | gimli
# Processing Record 43 of Set 4 | alofi
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | udayagiri
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | san rafael
# Processing Record 48 of Set 4 | bubaque
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 4 | najran
# Processing Record 1 of Set 5 | tura
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | mazatlan
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | sola
# Processing Record 7 of Set 5 | hornepayne
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | duluth
# Processing Record 10 of Set 5 | antofagasta
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | pindiga
# Processing Record 13 of Set 5 | altamira
# Processing Record 14 of Set 5 | tiksi
# Processing Record 15 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 5 | pangody
# Processing Record 17 of Set 5 | turukhansk
# Processing Record 18 of Set 5 | mira
# Processing Record 19 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 5 | luchegorsk
# Processing Record 21 of Set 5 | esperance
# Processing Record 22 of Set 5 | sungairaya
# Processing Record 23 of Set 5 | alice
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | puerto escondido
# Processing Record 26 of Set 5 | kanker
# Processing Record 27 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 5 | luanda
# Processing Record 29 of Set 5 | umm kaddadah
# Processing Record 30 of Set 5 | hondo
# Processing Record 31 of Set 5 | omsukchan
# Processing Record 32 of Set 5 | ardakan
# Processing Record 33 of Set 5 | boa vista
# Processing Record 34 of Set 5 | alice springs
# Processing Record 35 of Set 5 | hualmay
# Processing Record 36 of Set 5 | greeneville
# Processing Record 37 of Set 5 | qaqortoq
# Processing Record 38 of Set 5 | kodiak
# Processing Record 39 of Set 5 | necochea
# Processing Record 40 of Set 5 | fukuma
# Processing Record 41 of Set 5 | bouar
# Processing Record 42 of Set 5 | buga
# Processing Record 43 of Set 5 | port elizabeth
# Processing Record 44 of Set 5 | pilar
# Processing Record 45 of Set 5 | castle rock
# Processing Record 46 of Set 5 | kashin
# Processing Record 47 of Set 5 | waipawa
# Processing Record 48 of Set 5 | road town
# Processing Record 49 of Set 5 | kenora
# Processing Record 50 of Set 5 | betare oya
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | umba
# Processing Record 3 of Set 6 | fereydun kenar
# Processing Record 4 of Set 6 | angoram
# Processing Record 5 of Set 6 | newcastle
# Processing Record 6 of Set 6 | dakar
# Processing Record 7 of Set 6 | nome
# Processing Record 8 of Set 6 | san carlos de bariloche
# Processing Record 9 of Set 6 | marrakesh
# Processing Record 10 of Set 6 | jumla
# Processing Record 11 of Set 6 | puerto quijarro
# Processing Record 12 of Set 6 | walvis bay
# Processing Record 13 of Set 6 | fenyi
# Processing Record 14 of Set 6 | beringovskiy
# Processing Record 15 of Set 6 | roros
# Processing Record 16 of Set 6 | henties bay
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | eshowe
# Processing Record 19 of Set 6 | diplo
# Processing Record 20 of Set 6 | sangar
# Processing Record 21 of Set 6 | guliston
# Processing Record 22 of Set 6 | saint joseph
# Processing Record 23 of Set 6 | teya
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | hailar
# Processing Record 26 of Set 6 | bengkulu
# Processing Record 27 of Set 6 | dunedin
# Processing Record 28 of Set 6 | raga
# Processing Record 29 of Set 6 | san cristobal
# Processing Record 30 of Set 6 | cayenne
# Processing Record 31 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 6 | takoradi
# Processing Record 33 of Set 6 | richards bay
# Processing Record 34 of Set 6 | shorewood
# Processing Record 35 of Set 6 | vao
# Processing Record 36 of Set 6 | bereda
# Processing Record 37 of Set 6 | normandin
# Processing Record 38 of Set 6 | ciudad real
# Processing Record 39 of Set 6 | gladstone
# Processing Record 40 of Set 6 | coari
# Processing Record 41 of Set 6 | chato
# Processing Record 42 of Set 6 | emba
# Processing Record 43 of Set 6 | kutum
# Processing Record 44 of Set 6 | tuma
# Processing Record 45 of Set 6 | hirara
# Processing Record 46 of Set 6 | kirakira
# Processing Record 47 of Set 6 | impfondo
# Processing Record 48 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 6 | balikpapan
# Processing Record 50 of Set 6 | shekhupura
# Processing Record 1 of Set 7 | luderitz
# Processing Record 2 of Set 7 | arsenyev
# Processing Record 3 of Set 7 | loa janan
# Processing Record 4 of Set 7 | vadso
# Processing Record 5 of Set 7 | skibbereen
# Processing Record 6 of Set 7 | goure
# Processing Record 7 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 7 | phangnga
# Processing Record 9 of Set 7 | waddan
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | whitehorse
# Processing Record 12 of Set 7 | yibin
# Processing Record 13 of Set 7 | qunduz
# Processing Record 14 of Set 7 | sao felix do xingu
# Processing Record 15 of Set 7 | krasnouralsk
# Processing Record 16 of Set 7 | bagdarin
# Processing Record 17 of Set 7 | verkhnyaya inta
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | villanueva
# Processing Record 20 of Set 7 | manoel urbano
# Processing Record 21 of Set 7 | morros
# Processing Record 22 of Set 7 | mae sai
# Processing Record 23 of Set 7 | chipinge
# Processing Record 24 of Set 7 | pochinki
# Processing Record 25 of Set 7 | uva
# Processing Record 26 of Set 7 | ganzhou
# Processing Record 27 of Set 7 | nigran
# Processing Record 28 of Set 7 | tigil
# Processing Record 29 of Set 7 | barinas
# Processing Record 30 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 7 | taikang
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 7 | carutapera
# Processing Record 35 of Set 7 | morehead
# Processing Record 36 of Set 7 | pevek
# Processing Record 37 of Set 7 | dubbo
# Processing Record 38 of Set 7 | los algarrobos
# Processing Record 39 of Set 7 | manutuke
# Processing Record 40 of Set 7 | kosovo polje
# Processing Record 41 of Set 7 | eden
# Processing Record 42 of Set 7 | moron
# Processing Record 43 of Set 7 | cootamundra
# Processing Record 44 of Set 7 | akyab
# Processing Record 45 of Set 7 | sarany
# Processing Record 46 of Set 7 | brownsville
# Processing Record 47 of Set 7 | nemuro
# Processing Record 48 of Set 7 | kongolo
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | bosaso
# Processing Record 1 of Set 8 | gravdal
# Processing Record 2 of Set 8 | assai
# Processing Record 3 of Set 8 | ceara-mirim
# City not found. Skipping...
# Processing Record 4 of Set 8 | gat
# Processing Record 5 of Set 8 | kyabram
# Processing Record 6 of Set 8 | gdansk
# Processing Record 7 of Set 8 | middleton
# Processing Record 8 of Set 8 | moerai
# Processing Record 9 of Set 8 | bumba
# Processing Record 10 of Set 8 | oussouye
# Processing Record 11 of Set 8 | sangmelima
# Processing Record 12 of Set 8 | lata
# Processing Record 13 of Set 8 | bela
# Processing Record 14 of Set 8 | yuci
# Processing Record 15 of Set 8 | kalmar
# Processing Record 16 of Set 8 | dujuma
# City not found. Skipping...
# Processing Record 17 of Set 8 | kamenka
# Processing Record 18 of Set 8 | yarada
# Processing Record 19 of Set 8 | rexburg
# Processing Record 20 of Set 8 | sao joao da barra
# Processing Record 21 of Set 8 | yelizovo
# Processing Record 22 of Set 8 | lalmohan
# Processing Record 23 of Set 8 | zhifang
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | zanatepec
# City not found. Skipping...
# Processing Record 26 of Set 8 | matsuura
# Processing Record 27 of Set 8 | kerema
# Processing Record 28 of Set 8 | cuamba
# Processing Record 29 of Set 8 | mana
# Processing Record 30 of Set 8 | kosa
# Processing Record 31 of Set 8 | juruti
# Processing Record 32 of Set 8 | maarianhamina
# Processing Record 33 of Set 8 | kilindoni
# Processing Record 34 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 8 | nyurba
# Processing Record 36 of Set 8 | nang rong
# Processing Record 37 of Set 8 | vostok
# Processing Record 38 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 39 of Set 8 | launceston
# Processing Record 40 of Set 8 | maldonado
# Processing Record 41 of Set 8 | amga
# Processing Record 42 of Set 8 | muriti
# Processing Record 43 of Set 8 | auki
# Processing Record 44 of Set 8 | talgram
# Processing Record 45 of Set 8 | ezhou
# Processing Record 46 of Set 8 | san ramon
# Processing Record 47 of Set 8 | ejura
# Processing Record 48 of Set 8 | husavik
# Processing Record 49 of Set 8 | general roca
# Processing Record 50 of Set 8 | mount pleasant
# Processing Record 1 of Set 9 | harwich
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | voh
# Processing Record 4 of Set 9 | asmara
# Processing Record 5 of Set 9 | vinh
# Processing Record 6 of Set 9 | aliaga
# Processing Record 7 of Set 9 | warrington
# Processing Record 8 of Set 9 | uruzgan
# Processing Record 9 of Set 9 | micheweni
# Processing Record 10 of Set 9 | uzunovo
# Processing Record 11 of Set 9 | kumbo
# Processing Record 12 of Set 9 | itaituba
# Processing Record 13 of Set 9 | virden
# Processing Record 14 of Set 9 | nyuksenitsa
# Processing Record 15 of Set 9 | raudeberg
# Processing Record 16 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 9 | sistranda
# Processing Record 18 of Set 9 | tiznit
# Processing Record 19 of Set 9 | zurrieq
# Processing Record 20 of Set 9 | ostrovnoy
# Processing Record 21 of Set 9 | stornoway
# Processing Record 22 of Set 9 | dinard
# Processing Record 23 of Set 9 | outlook
# Processing Record 24 of Set 9 | pedernales
# Processing Record 25 of Set 9 | saint george
# Processing Record 26 of Set 9 | tessalit
# Processing Record 27 of Set 9 | la ronge
# Processing Record 28 of Set 9 | camana
# Processing Record 29 of Set 9 | thinadhoo
# Processing Record 30 of Set 9 | ferme-neuve
# Processing Record 31 of Set 9 | mayahi
# Processing Record 32 of Set 9 | jining
# Processing Record 33 of Set 9 | laminusa
# Processing Record 34 of Set 9 | beloha
# Processing Record 35 of Set 9 | paranaiba
# Processing Record 36 of Set 9 | rawson
# Processing Record 37 of Set 9 | gizo
# Processing Record 38 of Set 9 | mapastepec
# Processing Record 39 of Set 9 | ocos
# Processing Record 40 of Set 9 | aksu
# Processing Record 41 of Set 9 | santa rosa
# Processing Record 42 of Set 9 | kavaratti
# Processing Record 43 of Set 9 | palma
# Processing Record 44 of Set 9 | mayya
# Processing Record 45 of Set 9 | amahai
# Processing Record 46 of Set 9 | zeerust
# Processing Record 47 of Set 9 | port lincoln
# Processing Record 48 of Set 9 | yangambi
# Processing Record 49 of Set 9 | maneadero
# Processing Record 50 of Set 9 | port keats
# Processing Record 1 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 3 of Set 10 | naze
# Processing Record 4 of Set 10 | springhill
# Processing Record 5 of Set 10 | salalah
# Processing Record 6 of Set 10 | praia
# Processing Record 7 of Set 10 | saint-joseph
# Processing Record 8 of Set 10 | buraydah
# Processing Record 9 of Set 10 | susangerd
# Processing Record 10 of Set 10 | geraldton
# Processing Record 11 of Set 10 | galle
# Processing Record 12 of Set 10 | kataysk
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | meridian
# Processing Record 15 of Set 10 | marihatag
# Processing Record 16 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 10 | dauphin
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | berezovyy
# Processing Record 20 of Set 10 | mogadishu
# Processing Record 21 of Set 10 | lahad datu
# Processing Record 22 of Set 10 | ilulissat
# Processing Record 23 of Set 10 | wanning
# Processing Record 24 of Set 10 | nador
# Processing Record 25 of Set 10 | linxi
# Processing Record 26 of Set 10 | chitral
# Processing Record 27 of Set 10 | moletai
# Processing Record 28 of Set 10 | fuxin
# Processing Record 29 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 10 | orange
# Processing Record 31 of Set 10 | kambove
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | santa catalina
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | mengcheng
# Processing Record 36 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 10 | labytnangi
# Processing Record 38 of Set 10 | snezhnogorsk
# Processing Record 39 of Set 10 | santa maria da vitoria
# Processing Record 40 of Set 10 | tautira
# Processing Record 41 of Set 10 | san matias
# Processing Record 42 of Set 10 | saint-pierre
# Processing Record 43 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 10 | semnan
# Processing Record 45 of Set 10 | katsuura
# Processing Record 46 of Set 10 | pangkalanbuun
# Processing Record 47 of Set 10 | huarmey
# Processing Record 48 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 50 of Set 10 | monteagudo
# Processing Record 1 of Set 11 | saint anthony
# Processing Record 2 of Set 11 | toamasina
# Processing Record 3 of Set 11 | mosquera
# Processing Record 4 of Set 11 | conceicao do araguaia
# Processing Record 5 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 11 | terrace bay
# Processing Record 7 of Set 11 | ulaangom
# Processing Record 8 of Set 11 | barquisimeto
# Processing Record 9 of Set 11 | meulaboh
# Processing Record 10 of Set 11 | buala
# Processing Record 11 of Set 11 | matara
# Processing Record 12 of Set 11 | buta
# Processing Record 13 of Set 11 | vigrestad
# Processing Record 14 of Set 11 | doha
# Processing Record 15 of Set 11 | araouane
# Processing Record 16 of Set 11 | akhalgori
# Processing Record 17 of Set 11 | muros
# Processing Record 18 of Set 11 | saurimo
# Processing Record 19 of Set 11 | havoysund
# Processing Record 20 of Set 11 | sabac
# Processing Record 21 of Set 11 | hutchinson
# Processing Record 22 of Set 11 | kainantu
# Processing Record 23 of Set 11 | chhindwara
# Processing Record 24 of Set 11 | marienburg
# Processing Record 25 of Set 11 | namibe
# Processing Record 26 of Set 11 | kaeo
# Processing Record 27 of Set 11 | orichi
# Processing Record 28 of Set 11 | acapulco
# Processing Record 29 of Set 11 | kazerun
# Processing Record 30 of Set 11 | kamaishi
# Processing Record 31 of Set 11 | fazalpur
# Processing Record 32 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 11 | lavrentiya
# Processing Record 34 of Set 11 | killybegs
# Processing Record 35 of Set 11 | jerantut
# Processing Record 36 of Set 11 | wufeng
# Processing Record 37 of Set 11 | sobolevo
# Processing Record 38 of Set 11 | bowen
# Processing Record 39 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 11 | dalnegorsk
# Processing Record 41 of Set 11 | fairbanks
# Processing Record 42 of Set 11 | nicoya
# Processing Record 43 of Set 11 | sanming
# Processing Record 44 of Set 11 | fare
# Processing Record 45 of Set 11 | tshikapa
# Processing Record 46 of Set 11 | urucara
# Processing Record 47 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 11 | mahdasht
# Processing Record 49 of Set 11 | kirensk
# Processing Record 50 of Set 11 | batticaloa
# Processing Record 1 of Set 12 | kentau
# Processing Record 2 of Set 12 | salinopolis
# Processing Record 3 of Set 12 | longonjo
# Processing Record 4 of Set 12 | tazovskiy
# Processing Record 5 of Set 12 | sibu
# Processing Record 6 of Set 12 | rincon
# Processing Record 7 of Set 12 | srednekolymsk
# Processing Record 8 of Set 12 | muscat
# Processing Record 9 of Set 12 | batagay-alyta
# Processing Record 10 of Set 12 | shamkhal
# Processing Record 11 of Set 12 | banjar
# Processing Record 12 of Set 12 | vila velha
# Processing Record 13 of Set 12 | ekimchan
# Processing Record 14 of Set 12 | meadow lake
# Processing Record 15 of Set 12 | novo cruzeiro
# Processing Record 16 of Set 12 | gijon
# Processing Record 17 of Set 12 | dickinson
# Processing Record 18 of Set 12 | loandjili
# Processing Record 19 of Set 12 | mayumba
# Processing Record 20 of Set 12 | mae ramat
# Processing Record 21 of Set 12 | manacapuru
# Processing Record 22 of Set 12 | kumo
# Processing Record 23 of Set 12 | camocim
# Processing Record 24 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 25 of Set 12 | sakaiminato
# Processing Record 26 of Set 12 | kuminskiy
# Processing Record 27 of Set 12 | araguaina
# Processing Record 28 of Set 12 | turbat
# Processing Record 29 of Set 12 | sorland
# Processing Record 30 of Set 12 | sawtell
# Processing Record 31 of Set 12 | karia
# Processing Record 32 of Set 12 | cotonou
# Processing Record 33 of Set 12 | codrington
# Processing Record 34 of Set 12 | tashtyp
# Processing Record 35 of Set 12 | montes altos
# Processing Record 36 of Set 12 | taywarah
# Processing Record 37 of Set 12 | zhuhai
# Processing Record 38 of Set 12 | bac lieu
# Processing Record 39 of Set 12 | quelimane
# Processing Record 40 of Set 12 | balabac
# Processing Record 41 of Set 12 | krasnokholm
# Processing Record 42 of Set 12 | troitsk
# Processing Record 43 of Set 12 | leiyang
# Processing Record 44 of Set 12 | zasechnoye
# Processing Record 45 of Set 12 | swan hill
# Processing Record 46 of Set 12 | yangjiang
# Processing Record 47 of Set 12 | arandis
# Processing Record 48 of Set 12 | cooma
# Processing Record 49 of Set 12 | aksha
# Processing Record 50 of Set 12 | abashiri
# Processing Record 1 of Set 13 | ulladulla
# Processing Record 2 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | bandarbeyla
# Processing Record 4 of Set 13 | vidyayevo
# Processing Record 5 of Set 13 | ciudad bolivar
# Processing Record 6 of Set 13 | nelson bay
# Processing Record 7 of Set 13 | taltal
# Processing Record 8 of Set 13 | roma
# Processing Record 9 of Set 13 | kargasok
# Processing Record 10 of Set 13 | blythe
# Processing Record 11 of Set 13 | puerto del rosario
# Processing Record 12 of Set 13 | paamiut
# Processing Record 13 of Set 13 | zhigansk
# Processing Record 14 of Set 13 | corrales
# Processing Record 15 of Set 13 | quibdo
# Processing Record 16 of Set 13 | oni
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | inuvik
# Processing Record 19 of Set 13 | empangeni
# Processing Record 20 of Set 13 | novyy urengoy
# Processing Record 21 of Set 13 | vyazma
# Processing Record 22 of Set 13 | hanna
# Processing Record 23 of Set 13 | pandamatenga
# Processing Record 24 of Set 13 | bouza
# Processing Record 25 of Set 13 | nargana
# Processing Record 26 of Set 13 | mnogovershinnyy
# Processing Record 27 of Set 13 | neiafu
# Processing Record 28 of Set 13 | iquitos
# Processing Record 29 of Set 13 | san patricio
# Processing Record 30 of Set 13 | marica
# Processing Record 31 of Set 13 | kenai
# Processing Record 32 of Set 13 | rockford
# Processing Record 33 of Set 13 | tahoua
# Processing Record 34 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 13 | inirida
# Processing Record 36 of Set 13 | llaillay
# Processing Record 37 of Set 13 | manaure
# Processing Record 38 of Set 13 | abaza
# Processing Record 39 of Set 13 | kapoeta
# Processing Record 40 of Set 13 | siocon
# Processing Record 41 of Set 13 | zhanaozen
# Processing Record 42 of Set 13 | marawi
# Processing Record 43 of Set 13 | tsagveri
# Processing Record 44 of Set 13 | nhulunbuy
# Processing Record 45 of Set 13 | wampusirpi
# City not found. Skipping...
# Processing Record 46 of Set 13 | mizdah
# Processing Record 47 of Set 13 | pangnirtung
# Processing Record 48 of Set 13 | fort nelson
# Processing Record 49 of Set 13 | rafaela
# Processing Record 50 of Set 13 | vestmannaeyjar
# Processing Record 1 of Set 14 | moundou
# Processing Record 2 of Set 14 | bure
# Processing Record 3 of Set 14 | indramayu
# Processing Record 4 of Set 14 | ostersund
# Processing Record 5 of Set 14 | pandan
# Processing Record 6 of Set 14 | lompoc
# Processing Record 7 of Set 14 | redlands
# Processing Record 8 of Set 14 | sainte-rose
# Processing Record 9 of Set 14 | san quintin
# Processing Record 10 of Set 14 | balaipungut
# Processing Record 11 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 12 of Set 14 | ancud
# Processing Record 13 of Set 14 | port augusta
# Processing Record 14 of Set 14 | almaznyy
# Processing Record 15 of Set 14 | dillon
# Processing Record 16 of Set 14 | rajauri
# Processing Record 17 of Set 14 | santa cruz
# Processing Record 18 of Set 14 | mattru
# Processing Record 19 of Set 14 | ekhabi
# Processing Record 20 of Set 14 | lakhdenpokhya
# Processing Record 21 of Set 14 | karasuk
# Processing Record 22 of Set 14 | peniche
# Processing Record 23 of Set 14 | lawton
# Processing Record 24 of Set 14 | zalantun
# Processing Record 25 of Set 14 | nanzhou
# Processing Record 26 of Set 14 | bestobe
# Processing Record 27 of Set 14 | gebre guracha
# Processing Record 28 of Set 14 | manzanillo
# Processing Record 29 of Set 14 | shache
# Processing Record 30 of Set 14 | bulawayo
# Processing Record 31 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 33 of Set 14 | vysokogornyy
# Processing Record 34 of Set 14 | rovenki
# Processing Record 35 of Set 14 | sterling
# Processing Record 36 of Set 14 | urumqi
# Processing Record 37 of Set 14 | gilbues
# Processing Record 38 of Set 14 | verkhoyansk
# Processing Record 39 of Set 14 | benin
# Processing Record 40 of Set 14 | hashimoto
# Processing Record 41 of Set 14 | baruun-urt
# Processing Record 42 of Set 14 | mitu
# Processing Record 43 of Set 14 | shubarshi
# Processing Record 44 of Set 14 | gorom-gorom
# Processing Record 45 of Set 14 | altotonga
# Processing Record 46 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 14 | ketchikan
# Processing Record 49 of Set 14 | san pedro de uraba
# Processing Record 50 of Set 14 | xixiang
# Processing Record 1 of Set 15 | saint-augustin
# Processing Record 2 of Set 15 | baherden
# Processing Record 3 of Set 15 | calapi
# Processing Record 4 of Set 15 | nauta
# Processing Record 5 of Set 15 | azare
# Processing Record 6 of Set 15 | trairi
# Processing Record 7 of Set 15 | manalurpet
# City not found. Skipping...
# Processing Record 8 of Set 15 | tyrma
# Processing Record 9 of Set 15 | mildura
# Processing Record 10 of Set 15 | cedar lake
# Processing Record 11 of Set 15 | mayor pablo lagerenza
# Processing Record 12 of Set 15 | neftegorsk
# Processing Record 13 of Set 15 | san andres
# Processing Record 14 of Set 15 | nabire
# Processing Record 15 of Set 15 | catazaja
# Processing Record 16 of Set 15 | east bethel
# Processing Record 17 of Set 15 | simbahan
# Processing Record 18 of Set 15 | kankaanpaa
# Processing Record 19 of Set 15 | puerto cabezas
# Processing Record 20 of Set 15 | rapid valley
# Processing Record 21 of Set 15 | bira
# Processing Record 22 of Set 15 | sao gabriel
# Processing Record 23 of Set 15 | alta floresta
# Processing Record 24 of Set 15 | novaya ladoga
# Processing Record 25 of Set 15 | uglovskoye
# Processing Record 26 of Set 15 | iralaya
# Processing Record 27 of Set 15 | north bend
# Processing Record 28 of Set 15 | imisli
# City not found. Skipping...
# Processing Record 29 of Set 15 | porto novo
# Processing Record 30 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 15 | myitkyina
# Processing Record 32 of Set 15 | sabrum
# Processing Record 33 of Set 15 | nanga eboko
# Processing Record 34 of Set 15 | koplik
# Processing Record 35 of Set 15 | kefamenanu
# Processing Record 36 of Set 15 | ojiya
# Processing Record 37 of Set 15 | keti bandar
# Processing Record 38 of Set 15 | miraflores
# Processing Record 39 of Set 15 | sinnamary
# Processing Record 40 of Set 15 | deputatskiy
# Processing Record 41 of Set 15 | zhangjiakou
# Processing Record 42 of Set 15 | bulolo
# Processing Record 43 of Set 15 | ust-nera
# Processing Record 44 of Set 15 | luganville
# Processing Record 45 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 46 of Set 15 | huicheng
# Processing Record 47 of Set 15 | hohhot
# Processing Record 48 of Set 15 | marsta
# Processing Record 49 of Set 15 | marfino
# Processing Record 50 of Set 15 | chingirlau
# Processing Record 1 of Set 16 | lusambo
# Processing Record 2 of Set 16 | yugorsk
# Processing Record 3 of Set 16 | vitimskiy
# City not found. Skipping...
# Processing Record 4 of Set 16 | pangai
# Processing Record 5 of Set 16 | arlit
# Processing Record 6 of Set 16 | swan river
# Processing Record 7 of Set 16 | tulum
# Processing Record 8 of Set 16 | las palmas
# Processing Record 9 of Set 16 | evensk
# Processing Record 10 of Set 16 | leshukonskoye
# Processing Record 11 of Set 16 | camacha
# Processing Record 12 of Set 16 | korla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp Current Description  \
# 0               Ushuaia -54.8000  -68.3000     53.26    scattered clouds
# 1  Vila Franca Do Campo  37.7167  -25.4333     61.21     overcast clouds
# 2             Cape Town -33.9258   18.4232     65.91          few clouds
# 3            Nikolskoye  59.7035   30.7861     31.91    scattered clouds
# 4              Cidreira -30.1811  -50.2056     75.96     overcast clouds
# 5                 Airai  -8.9266  125.4092     60.31     overcast clouds
# 6              Cherskiy  68.7500  161.3000    -15.50     overcast clouds
# 7                Carnot   4.9409   15.8665     75.22       broken clouds
# 8               Caborca  30.5838 -111.1010     68.92     overcast clouds
# 9               Biloela -24.4167  150.5000     68.54       broken clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        54          40       14.97      AR
# 1        83          96        8.16      PT
# 2        87          20        5.75      ZA
# 3        86          33        6.04      RU
# 4        78          88       11.05      BR
# 5        90         100        1.03      TL
# 6        98         100        7.36      RU
# 7        68          63        3.85      CF
# 8        42         100       24.02      MX
# 9        71          51        7.14      AU

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", 
                    "Current Description"] 


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
    

# Display sample data
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Ushuaia      AR -54.8000  -68.3000     53.26        54
# 1  Vila Franca Do Campo      PT  37.7167  -25.4333     61.21        83
# 2             Cape Town      ZA -33.9258   18.4232     65.91        87
# 3            Nikolskoye      RU  59.7035   30.7861     31.91        86
# 4              Cidreira      BR -30.1811  -50.2056     75.96        78
# 5                 Airai      TL  -8.9266  125.4092     60.31        90
# 6              Cherskiy      RU  68.7500  161.3000    -15.50        98
# 7                Carnot      CF   4.9409   15.8665     75.22        68
# 8               Caborca      MX  30.5838 -111.1010     68.92        42
# 9               Biloela      AU -24.4167  150.5000     68.54        71
#
#    Cloudiness  Wind Speed Current Description
# 0          40       14.97    scattered clouds
# 1          96        8.16     overcast clouds
# 2          20        5.75          few clouds
# 3          33        6.04    scattered clouds
# 4          88       11.05     overcast clouds
# 5         100        1.03     overcast clouds
# 6         100        7.36     overcast clouds
# 7          63        3.85       broken clouds
# 8         100       24.02     overcast clouds
# 9          51        7.14       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
