# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 764

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dd4489015a0d53691a4504c482fe26b5

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shihezi
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | buzmeyin
# Processing Record 5 of Set 1 | sambava
# Processing Record 6 of Set 1 | bandarbeyla
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | ciudad valles
# Processing Record 9 of Set 1 | san jose
# Processing Record 10 of Set 1 | sabha
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | saint combs
# City not found. Skipping...
# Processing Record 13 of Set 1 | basco
# Processing Record 14 of Set 1 | rudnichnyy
# Processing Record 15 of Set 1 | te anau
# Processing Record 16 of Set 1 | taksimo
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | playa del carmen
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | coahuayana
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 1 | gandai
# Processing Record 33 of Set 1 | isangel
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | colesberg
# Processing Record 40 of Set 1 | izumo
# Processing Record 41 of Set 1 | araouane
# Processing Record 42 of Set 1 | kavaratti
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | mayo
# Processing Record 47 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 1 | rocha
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | bilibino
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | antofagasta
# Processing Record 4 of Set 2 | manaure
# Processing Record 5 of Set 2 | san cristobal
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | taoudenni
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | pringsewu
# Processing Record 12 of Set 2 | gavrilovka vtoraya
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | salinopolis
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | cabedelo
# Processing Record 18 of Set 2 | christchurch
# Processing Record 19 of Set 2 | nang rong
# Processing Record 20 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | sao joao da barra
# Processing Record 23 of Set 2 | arraial do cabo
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | fukue
# Processing Record 26 of Set 2 | ucluelet
# Processing Record 27 of Set 2 | bonthe
# Processing Record 28 of Set 2 | grand gaube
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | vohringen
# Processing Record 31 of Set 2 | korla
# Processing Record 32 of Set 2 | aswan
# Processing Record 33 of Set 2 | abha
# Processing Record 34 of Set 2 | alice springs
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | pochutla
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | semey
# Processing Record 39 of Set 2 | port blair
# Processing Record 40 of Set 2 | castlegar
# Processing Record 41 of Set 2 | macamic
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | namie
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | sabang
# Processing Record 46 of Set 2 | boueni
# Processing Record 47 of Set 2 | ushuaia
# Processing Record 48 of Set 2 | tooele
# Processing Record 49 of Set 2 | cape canaveral
# Processing Record 50 of Set 2 | inta
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | pemangkat
# Processing Record 7 of Set 3 | adrar
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | dutse
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | pevek
# Processing Record 12 of Set 3 | mamallapuram
# Processing Record 13 of Set 3 | ketchikan
# Processing Record 14 of Set 3 | burns lake
# Processing Record 15 of Set 3 | tahe
# Processing Record 16 of Set 3 | asfi
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | moncao
# Processing Record 20 of Set 3 | curvelo
# Processing Record 21 of Set 3 | sola
# Processing Record 22 of Set 3 | kodino
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | denpasar
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | bida
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | flagstaff
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | zaraysk
# Processing Record 32 of Set 3 | nantucket
# Processing Record 33 of Set 3 | erenhot
# Processing Record 34 of Set 3 | mongo
# Processing Record 35 of Set 3 | albany
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | lensk
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | bati
# Processing Record 42 of Set 3 | tual
# Processing Record 43 of Set 3 | dongsheng
# Processing Record 44 of Set 3 | victoria
# Processing Record 45 of Set 3 | boyolangu
# Processing Record 46 of Set 3 | lorengau
# Processing Record 47 of Set 3 | vao
# Processing Record 48 of Set 3 | yar-sale
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 4 | soe
# Processing Record 2 of Set 4 | muravlenko
# Processing Record 3 of Set 4 | teya
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | aquiraz
# Processing Record 6 of Set 4 | burnie
# Processing Record 7 of Set 4 | elizabeth city
# Processing Record 8 of Set 4 | raudeberg
# Processing Record 9 of Set 4 | guerrero negro
# Processing Record 10 of Set 4 | ozerne
# Processing Record 11 of Set 4 | north platte
# Processing Record 12 of Set 4 | paceco
# Processing Record 13 of Set 4 | vostok
# Processing Record 14 of Set 4 | mizdah
# Processing Record 15 of Set 4 | iquitos
# Processing Record 16 of Set 4 | komsomolskiy
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | estevan
# Processing Record 19 of Set 4 | vilyuysk
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | verkhoyansk
# Processing Record 22 of Set 4 | the pas
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | pangnirtung
# Processing Record 27 of Set 4 | fez
# Processing Record 28 of Set 4 | jacksonville
# Processing Record 29 of Set 4 | monte alegre
# Processing Record 30 of Set 4 | porto novo
# Processing Record 31 of Set 4 | tessalit
# Processing Record 32 of Set 4 | rio gallegos
# Processing Record 33 of Set 4 | tazovskiy
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | mabaruma
# Processing Record 38 of Set 4 | praia da vitoria
# Processing Record 39 of Set 4 | tiarei
# Processing Record 40 of Set 4 | singaraja
# Processing Record 41 of Set 4 | hirara
# Processing Record 42 of Set 4 | kamina
# Processing Record 43 of Set 4 | eureka
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | praya
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 49 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | matamoros
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | lebu
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | warman
# Processing Record 8 of Set 5 | saint-philippe
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | katobu
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | san ramon
# Processing Record 13 of Set 5 | nueve de julio
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | nanlong
# Processing Record 16 of Set 5 | songkhla
# Processing Record 17 of Set 5 | nouadhibou
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | ostrovnoy
# Processing Record 20 of Set 5 | kango
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | prainha
# Processing Record 23 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 5 | lasa
# Processing Record 25 of Set 5 | acajutla
# Processing Record 26 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | namatanai
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | viedma
# Processing Record 30 of Set 5 | yarovoye
# Processing Record 31 of Set 5 | padang
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | derzhavinsk
# Processing Record 35 of Set 5 | canton
# Processing Record 36 of Set 5 | gasa
# Processing Record 37 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 5 | tevaitoa
# Processing Record 39 of Set 5 | petropavlovka
# Processing Record 40 of Set 5 | zhigansk
# Processing Record 41 of Set 5 | lady lake
# Processing Record 42 of Set 5 | mandalgovi
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | bowen
# Processing Record 45 of Set 5 | meulaboh
# Processing Record 46 of Set 5 | comodoro rivadavia
# Processing Record 47 of Set 5 | san vicente
# Processing Record 48 of Set 5 | khatanga
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | matara
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | catamarca
# Processing Record 3 of Set 6 | olafsvik
# Processing Record 4 of Set 6 | georgetown
# Processing Record 5 of Set 6 | moose factory
# Processing Record 6 of Set 6 | thompson
# Processing Record 7 of Set 6 | tias
# Processing Record 8 of Set 6 | columbus
# Processing Record 9 of Set 6 | hurghada
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | road town
# Processing Record 12 of Set 6 | vardo
# Processing Record 13 of Set 6 | ambon
# Processing Record 14 of Set 6 | wichita falls
# Processing Record 15 of Set 6 | san andres
# Processing Record 16 of Set 6 | le port
# Processing Record 17 of Set 6 | tahlequah
# Processing Record 18 of Set 6 | puerto rondon
# Processing Record 19 of Set 6 | trairi
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | port hedland
# Processing Record 22 of Set 6 | zhanaozen
# Processing Record 23 of Set 6 | goderich
# Processing Record 24 of Set 6 | linfen
# Processing Record 25 of Set 6 | baoro
# Processing Record 26 of Set 6 | reconquista
# Processing Record 27 of Set 6 | peleduy
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | ambovombe
# Processing Record 30 of Set 6 | plettenberg bay
# Processing Record 31 of Set 6 | nara
# Processing Record 32 of Set 6 | zhezkazgan
# Processing Record 33 of Set 6 | kijang
# Processing Record 34 of Set 6 | mount gambier
# Processing Record 35 of Set 6 | nikolskoye
# Processing Record 36 of Set 6 | natal
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | panama city
# Processing Record 39 of Set 6 | hwange
# Processing Record 40 of Set 6 | lisakovsk
# Processing Record 41 of Set 6 | hofn
# Processing Record 42 of Set 6 | acapulco
# Processing Record 43 of Set 6 | saint-joseph
# Processing Record 44 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | iacu
# Processing Record 46 of Set 6 | emba
# Processing Record 47 of Set 6 | saint george
# Processing Record 48 of Set 6 | mumford
# Processing Record 49 of Set 6 | general roca
# Processing Record 50 of Set 6 | port keats
# Processing Record 1 of Set 7 | severo-kurilsk
# Processing Record 2 of Set 7 | harper
# Processing Record 3 of Set 7 | casa branca
# Processing Record 4 of Set 7 | clonakilty
# Processing Record 5 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 7 | shache
# Processing Record 7 of Set 7 | ibra
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | yilan
# Processing Record 10 of Set 7 | alofi
# Processing Record 11 of Set 7 | chumikan
# Processing Record 12 of Set 7 | turayf
# Processing Record 13 of Set 7 | shimanovsk
# Processing Record 14 of Set 7 | el triunfo
# Processing Record 15 of Set 7 | north bend
# Processing Record 16 of Set 7 | erzin
# Processing Record 17 of Set 7 | trois-rivieres
# Processing Record 18 of Set 7 | varkaus
# Processing Record 19 of Set 7 | yugorsk
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | zhuhai
# Processing Record 22 of Set 7 | deputatskiy
# Processing Record 23 of Set 7 | burica
# City not found. Skipping...
# Processing Record 24 of Set 7 | baghmara
# Processing Record 25 of Set 7 | kaabong
# Processing Record 26 of Set 7 | nizwa
# Processing Record 27 of Set 7 | saskylakh
# Processing Record 28 of Set 7 | karlskrona
# Processing Record 29 of Set 7 | saint-francois
# Processing Record 30 of Set 7 | kahului
# Processing Record 31 of Set 7 | kruisfontein
# Processing Record 32 of Set 7 | tornio
# Processing Record 33 of Set 7 | abalak
# Processing Record 34 of Set 7 | souillac
# Processing Record 35 of Set 7 | kashi
# Processing Record 36 of Set 7 | ola
# Processing Record 37 of Set 7 | punta alta
# Processing Record 38 of Set 7 | nyon
# Processing Record 39 of Set 7 | pisco
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | port angeles
# Processing Record 42 of Set 7 | seymchan
# Processing Record 43 of Set 7 | tyup
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | san lorenzo
# Processing Record 46 of Set 7 | manavalakurichi
# Processing Record 47 of Set 7 | rognan
# Processing Record 48 of Set 7 | peto
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | urengoy
# Processing Record 1 of Set 8 | patnos
# Processing Record 2 of Set 8 | gua musang
# Processing Record 3 of Set 8 | salalah
# Processing Record 4 of Set 8 | the valley
# Processing Record 5 of Set 8 | pekan
# Processing Record 6 of Set 8 | minab
# Processing Record 7 of Set 8 | mana
# Processing Record 8 of Set 8 | bairiki
# Processing Record 9 of Set 8 | khawhai
# Processing Record 10 of Set 8 | brae
# Processing Record 11 of Set 8 | nome
# Processing Record 12 of Set 8 | itoman
# Processing Record 13 of Set 8 | macherla
# Processing Record 14 of Set 8 | opuwo
# Processing Record 15 of Set 8 | khandyga
# Processing Record 16 of Set 8 | dagana
# Processing Record 17 of Set 8 | castlerea
# Processing Record 18 of Set 8 | tahta
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | visby
# Processing Record 21 of Set 8 | impfondo
# Processing Record 22 of Set 8 | bull savanna
# Processing Record 23 of Set 8 | kieta
# Processing Record 24 of Set 8 | grand-lahou
# Processing Record 25 of Set 8 | mahon
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 8 | bloomfield
# Processing Record 29 of Set 8 | mount isa
# Processing Record 30 of Set 8 | margate
# Processing Record 31 of Set 8 | sylvan lake
# Processing Record 32 of Set 8 | forbes
# Processing Record 33 of Set 8 | shitanjing
# Processing Record 34 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 8 | terney
# Processing Record 36 of Set 8 | pemagatsel
# Processing Record 37 of Set 8 | inhambane
# Processing Record 38 of Set 8 | santa cruz
# Processing Record 39 of Set 8 | yeniseysk
# Processing Record 40 of Set 8 | polovinnoye
# Processing Record 41 of Set 8 | racale
# Processing Record 42 of Set 8 | tautira
# Processing Record 43 of Set 8 | vestmannaeyjar
# Processing Record 44 of Set 8 | kyra
# Processing Record 45 of Set 8 | ihosy
# Processing Record 46 of Set 8 | belmonte
# Processing Record 47 of Set 8 | ngaoundere
# Processing Record 48 of Set 8 | jacareacanga
# Processing Record 49 of Set 8 | tecoanapa
# Processing Record 50 of Set 8 | berbera
# Processing Record 1 of Set 9 | najran
# Processing Record 2 of Set 9 | youkounkoun
# Processing Record 3 of Set 9 | turukhansk
# Processing Record 4 of Set 9 | nepa nagar
# Processing Record 5 of Set 9 | dondo
# Processing Record 6 of Set 9 | labuhan
# Processing Record 7 of Set 9 | atbasar
# Processing Record 8 of Set 9 | ordynskoye
# Processing Record 9 of Set 9 | lebyazhye
# Processing Record 10 of Set 9 | syracuse
# Processing Record 11 of Set 9 | pine bluff
# Processing Record 12 of Set 9 | jiujiang
# Processing Record 13 of Set 9 | somerset
# Processing Record 14 of Set 9 | salym
# Processing Record 15 of Set 9 | sao gabriel da cachoeira
# Processing Record 16 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 9 | lata
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | itarema
# Processing Record 20 of Set 9 | benguela
# Processing Record 21 of Set 9 | klyuchi
# Processing Record 22 of Set 9 | luderitz
# Processing Record 23 of Set 9 | kang
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 9 | banjar
# Processing Record 27 of Set 9 | imbituba
# Processing Record 28 of Set 9 | heihe
# Processing Record 29 of Set 9 | cumra
# Processing Record 30 of Set 9 | srednekolymsk
# Processing Record 31 of Set 9 | trelew
# Processing Record 32 of Set 9 | groningen
# Processing Record 33 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 9 | nhulunbuy
# Processing Record 35 of Set 9 | tateyama
# Processing Record 36 of Set 9 | camana
# Processing Record 37 of Set 9 | kampong thum
# Processing Record 38 of Set 9 | port macquarie
# Processing Record 39 of Set 9 | taltal
# Processing Record 40 of Set 9 | terrace
# Processing Record 41 of Set 9 | fresnillo
# Processing Record 42 of Set 9 | cherskiy
# Processing Record 43 of Set 9 | aktash
# Processing Record 44 of Set 9 | aksu
# Processing Record 45 of Set 9 | bakreswar
# Processing Record 46 of Set 9 | half moon bay
# Processing Record 47 of Set 9 | buchanan
# Processing Record 48 of Set 9 | ukiah
# Processing Record 49 of Set 9 | jiwani
# Processing Record 50 of Set 9 | cortona
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | yulara
# Processing Record 3 of Set 10 | zhangjiakou
# Processing Record 4 of Set 10 | tacub
# Processing Record 5 of Set 10 | kloulklubed
# Processing Record 6 of Set 10 | dzerzhinskoye
# Processing Record 7 of Set 10 | yichang
# Processing Record 8 of Set 10 | kamiiso
# Processing Record 9 of Set 10 | bilara
# Processing Record 10 of Set 10 | severo-yeniseyskiy
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | santa isabel
# Processing Record 13 of Set 10 | ashtian
# Processing Record 14 of Set 10 | kasangulu
# Processing Record 15 of Set 10 | sumkino
# Processing Record 16 of Set 10 | buraydah
# Processing Record 17 of Set 10 | kenora
# Processing Record 18 of Set 10 | champerico
# Processing Record 19 of Set 10 | hamilton
# Processing Record 20 of Set 10 | lakes entrance
# Processing Record 21 of Set 10 | esmeraldas
# Processing Record 22 of Set 10 | weligama
# Processing Record 23 of Set 10 | leningradskiy
# Processing Record 24 of Set 10 | kenai
# Processing Record 25 of Set 10 | ilulissat
# Processing Record 26 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 10 | amahai
# Processing Record 28 of Set 10 | sitka
# Processing Record 29 of Set 10 | micomeseng
# Processing Record 30 of Set 10 | hervey bay
# Processing Record 31 of Set 10 | hereford
# Processing Record 32 of Set 10 | nemuro
# Processing Record 33 of Set 10 | kaeng khlo
# City not found. Skipping...
# Processing Record 34 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 10 | camopi
# Processing Record 36 of Set 10 | bosaso
# Processing Record 37 of Set 10 | narsaq
# Processing Record 38 of Set 10 | zharkent
# Processing Record 39 of Set 10 | kulhudhuffushi
# Processing Record 40 of Set 10 | udachnyy
# Processing Record 41 of Set 10 | asino
# Processing Record 42 of Set 10 | bonavista
# Processing Record 43 of Set 10 | mahajanga
# Processing Record 44 of Set 10 | wagar
# Processing Record 45 of Set 10 | nuuk
# Processing Record 46 of Set 10 | chulym
# Processing Record 47 of Set 10 | awbari
# Processing Record 48 of Set 10 | arrecife
# Processing Record 49 of Set 10 | floro
# Processing Record 50 of Set 10 | byron bay
# Processing Record 1 of Set 11 | maicao
# Processing Record 2 of Set 11 | roma
# Processing Record 3 of Set 11 | tete
# Processing Record 4 of Set 11 | bonnyville
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | okato
# Processing Record 7 of Set 11 | casper
# Processing Record 8 of Set 11 | liepaja
# Processing Record 9 of Set 11 | airai
# Processing Record 10 of Set 11 | chernyshevskiy
# Processing Record 11 of Set 11 | cortez
# Processing Record 12 of Set 11 | yining
# Processing Record 13 of Set 11 | golden rock
# City not found. Skipping...
# Processing Record 14 of Set 11 | gisborne
# Processing Record 15 of Set 11 | umuarama
# Processing Record 16 of Set 11 | calvinia
# Processing Record 17 of Set 11 | faranah
# Processing Record 18 of Set 11 | kirakira
# Processing Record 19 of Set 11 | kalavad
# Processing Record 20 of Set 11 | manuk mangkaw
# Processing Record 21 of Set 11 | luanda
# Processing Record 22 of Set 11 | batticaloa
# Processing Record 23 of Set 11 | dzidzantun
# Processing Record 24 of Set 11 | viru
# Processing Record 25 of Set 11 | broome
# Processing Record 26 of Set 11 | xining
# Processing Record 27 of Set 11 | dunedin
# Processing Record 28 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 11 | rapid valley
# Processing Record 30 of Set 11 | ville-marie
# Processing Record 31 of Set 11 | jodar
# Processing Record 32 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 11 | thap than
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | mitsamiouli
# Processing Record 36 of Set 11 | cervo
# Processing Record 37 of Set 11 | salinas
# Processing Record 38 of Set 11 | uige
# Processing Record 39 of Set 11 | olinda
# Processing Record 40 of Set 11 | itupiranga
# Processing Record 41 of Set 11 | samarai
# Processing Record 42 of Set 11 | cantagalo
# Processing Record 43 of Set 11 | phibun mangsahan
# Processing Record 44 of Set 11 | lakselv
# Processing Record 45 of Set 11 | aksarka
# Processing Record 46 of Set 11 | namibe
# Processing Record 47 of Set 11 | zaysan
# Processing Record 48 of Set 11 | khuzhir
# Processing Record 49 of Set 11 | wagga wagga
# Processing Record 50 of Set 11 | gao
# Processing Record 1 of Set 12 | san pedro
# Processing Record 2 of Set 12 | college
# Processing Record 3 of Set 12 | vila velha
# Processing Record 4 of Set 12 | carauari
# Processing Record 5 of Set 12 | sukhobezvodnoye
# Processing Record 6 of Set 12 | viramgam
# Processing Record 7 of Set 12 | san patricio
# Processing Record 8 of Set 12 | tomatlan
# Processing Record 9 of Set 12 | capanema
# Processing Record 10 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 12 | codrington
# Processing Record 12 of Set 12 | vanderhoof
# Processing Record 13 of Set 12 | la ronge
# Processing Record 14 of Set 12 | nanakuli
# Processing Record 15 of Set 12 | kudahuvadhoo
# Processing Record 16 of Set 12 | camacha
# Processing Record 17 of Set 12 | san carlos de bariloche
# Processing Record 18 of Set 12 | launceston
# Processing Record 19 of Set 12 | nioro
# Processing Record 20 of Set 12 | ribas do rio pardo
# Processing Record 21 of Set 12 | joshimath
# Processing Record 22 of Set 12 | karasburg
# Processing Record 23 of Set 12 | tambopata
# Processing Record 24 of Set 12 | solnechnyy
# Processing Record 25 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | norfolk
# Processing Record 27 of Set 12 | bilma
# Processing Record 28 of Set 12 | jeremie
# Processing Record 29 of Set 12 | saint-georges
# Processing Record 30 of Set 12 | yokadouma
# Processing Record 31 of Set 12 | tres arroyos
# Processing Record 32 of Set 12 | nambour
# Processing Record 33 of Set 12 | egvekinot
# Processing Record 34 of Set 12 | guilin
# Processing Record 35 of Set 12 | honiara
# Processing Record 36 of Set 12 | kuryk
# Processing Record 37 of Set 12 | pangai
# Processing Record 38 of Set 12 | krasnoselkup
# Processing Record 39 of Set 12 | fort nelson
# Processing Record 40 of Set 12 | shimoda
# Processing Record 41 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 12 | oranjestad
# Processing Record 43 of Set 12 | rosa zarate
# Processing Record 44 of Set 12 | kaeo
# Processing Record 45 of Set 12 | kitimat
# Processing Record 46 of Set 12 | poum
# Processing Record 47 of Set 12 | jacqueville
# Processing Record 48 of Set 12 | scarborough
# Processing Record 49 of Set 12 | corpus christi
# Processing Record 50 of Set 12 | richards bay
# Processing Record 1 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 2 of Set 13 | arcata
# Processing Record 3 of Set 13 | elat
# Processing Record 4 of Set 13 | markivka
# Processing Record 5 of Set 13 | northam
# Processing Record 6 of Set 13 | jambi
# Processing Record 7 of Set 13 | gat
# Processing Record 8 of Set 13 | marienburg
# Processing Record 9 of Set 13 | sao jose da coroa grande
# Processing Record 10 of Set 13 | karpathos
# Processing Record 11 of Set 13 | datia
# Processing Record 12 of Set 13 | piacabucu
# Processing Record 13 of Set 13 | paamiut
# Processing Record 14 of Set 13 | ubrique
# Processing Record 15 of Set 13 | carlsbad
# Processing Record 16 of Set 13 | falun
# Processing Record 17 of Set 13 | coracora
# Processing Record 18 of Set 13 | santa maria
# Processing Record 19 of Set 13 | manono
# Processing Record 20 of Set 13 | campbell river
# Processing Record 21 of Set 13 | weihai
# Processing Record 22 of Set 13 | san joaquin
# Processing Record 23 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 13 | ust-kuyga
# Processing Record 25 of Set 13 | itaberai
# Processing Record 26 of Set 13 | laguna
# Processing Record 27 of Set 13 | vanavara
# Processing Record 28 of Set 13 | puerto carreno
# Processing Record 29 of Set 13 | vallenar
# Processing Record 30 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 13 | sao joao do piaui
# Processing Record 32 of Set 13 | teguise
# Processing Record 33 of Set 13 | meru
# Processing Record 34 of Set 13 | nenjiang
# Processing Record 35 of Set 13 | sao borja
# Processing Record 36 of Set 13 | galle
# Processing Record 37 of Set 13 | fortuna
# Processing Record 38 of Set 13 | sindor
# Processing Record 39 of Set 13 | pokosnoye
# Processing Record 40 of Set 13 | labrea
# Processing Record 41 of Set 13 | mungwi
# Processing Record 42 of Set 13 | ostrowiec swietokrzyski
# Processing Record 43 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 13 | kabansk
# Processing Record 45 of Set 13 | jiamusi
# Processing Record 46 of Set 13 | verkhnevilyuysk
# Processing Record 47 of Set 13 | suluq
# Processing Record 48 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 13 | kozlovka
# Processing Record 50 of Set 13 | valparaiso
# Processing Record 1 of Set 14 | cockburn town
# Processing Record 2 of Set 14 | urucui
# Processing Record 3 of Set 14 | martapura
# Processing Record 4 of Set 14 | clarksville
# Processing Record 5 of Set 14 | oktyabrskiy
# Processing Record 6 of Set 14 | churapcha
# Processing Record 7 of Set 14 | skegness
# Processing Record 8 of Set 14 | fairbanks
# Processing Record 9 of Set 14 | bykovo
# Processing Record 10 of Set 14 | kichera
# Processing Record 11 of Set 14 | boras
# Processing Record 12 of Set 14 | port moresby
# Processing Record 13 of Set 14 | yerbogachen
# Processing Record 14 of Set 14 | abadan
# Processing Record 15 of Set 14 | naron
# Processing Record 16 of Set 14 | maarianhamina
# Processing Record 17 of Set 14 | castanos
# Processing Record 18 of Set 14 | atambua
# Processing Record 19 of Set 14 | saint anthony
# Processing Record 20 of Set 14 | tolaga bay
# Processing Record 21 of Set 14 | goure
# Processing Record 22 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 23 of Set 14 | bergen
# Processing Record 24 of Set 14 | bahia blanca
# Processing Record 25 of Set 14 | yasnogorsk
# Processing Record 26 of Set 14 | pitimbu
# Processing Record 27 of Set 14 | kinshasa
# Processing Record 28 of Set 14 | port augusta
# Processing Record 29 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 14 | bundaberg
# Processing Record 31 of Set 14 | manthani
# Processing Record 32 of Set 14 | katherine
# Processing Record 33 of Set 14 | yamethin
# Processing Record 34 of Set 14 | chimore
# Processing Record 35 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 14 | beckley
# Processing Record 37 of Set 14 | hovd
# Processing Record 38 of Set 14 | sibolga
# Processing Record 39 of Set 14 | baruun-urt
# Processing Record 40 of Set 14 | rawlins
# Processing Record 41 of Set 14 | hami
# Processing Record 42 of Set 14 | sohag
# Processing Record 43 of Set 14 | porto velho
# Processing Record 44 of Set 14 | umm kaddadah
# Processing Record 45 of Set 14 | sri aman
# Processing Record 46 of Set 14 | cacador
# Processing Record 47 of Set 14 | arman
# Processing Record 48 of Set 14 | hornepayne
# Processing Record 49 of Set 14 | rochegda
# Processing Record 50 of Set 14 | asht
# City not found. Skipping...
# Processing Record 1 of Set 15 | shchuchye
# City not found. Skipping...
# Processing Record 2 of Set 15 | alizai
# Processing Record 3 of Set 15 | san quintin
# Processing Record 4 of Set 15 | obo
# Processing Record 5 of Set 15 | naryan-mar
# Processing Record 6 of Set 15 | corn island
# Processing Record 7 of Set 15 | mehamn
# Processing Record 8 of Set 15 | pompeu
# Processing Record 9 of Set 15 | pasuruan
# Processing Record 10 of Set 15 | irbeyskoye
# Processing Record 11 of Set 15 | gelnica
# Processing Record 12 of Set 15 | nkhotakota
# Processing Record 13 of Set 15 | bugiri
# Processing Record 14 of Set 15 | cozumel
# Processing Record 15 of Set 15 | bucerias
# Processing Record 16 of Set 15 | bose
# Processing Record 17 of Set 15 | muros
# Processing Record 18 of Set 15 | amarillo
# Processing Record 19 of Set 15 | skjervoy
# Processing Record 20 of Set 15 | cocorit
# Processing Record 21 of Set 15 | palauig
# Processing Record 22 of Set 15 | zemio
# Processing Record 23 of Set 15 | novoagansk
# Processing Record 24 of Set 15 | fereydun kenar
# Processing Record 25 of Set 15 | yarmouth
# Processing Record 26 of Set 15 | dingle
# Processing Record 27 of Set 15 | surt
# Processing Record 28 of Set 15 | litovko
# Processing Record 29 of Set 15 | rogovatoye
# Processing Record 30 of Set 15 | imeni telmana
# City not found. Skipping...
# Processing Record 31 of Set 15 | vernon
# Processing Record 32 of Set 15 | agadez
# Processing Record 33 of Set 15 | dalvik
# Processing Record 34 of Set 15 | damietta
# Processing Record 35 of Set 15 | kapit
# Processing Record 36 of Set 15 | alyangula
# Processing Record 37 of Set 15 | taketa
# Processing Record 38 of Set 15 | voyvozh
# Processing Record 39 of Set 15 | qui nhon
# Processing Record 40 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 15 | virden
# Processing Record 42 of Set 15 | severobaykalsk
# Processing Record 43 of Set 15 | davila
# Processing Record 44 of Set 15 | brookhaven
# Processing Record 45 of Set 15 | makakilo city
# Processing Record 46 of Set 15 | kununurra
# Processing Record 47 of Set 15 | kamenka
# Processing Record 48 of Set 15 | lichuan
# Processing Record 49 of Set 15 | bayan
# Processing Record 50 of Set 15 | nawabganj
# Processing Record 1 of Set 16 | dina
# Processing Record 2 of Set 16 | kamskiye polyany
# Processing Record 3 of Set 16 | gambela
# Processing Record 4 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 16 | dwarka
# Processing Record 6 of Set 16 | leh
# Processing Record 7 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 16 | sindi
# Processing Record 9 of Set 16 | chicama
# Processing Record 10 of Set 16 | nanortalik
# Processing Record 11 of Set 16 | buon me thuot
# City not found. Skipping...
# Processing Record 12 of Set 16 | nagar karnul
# Processing Record 13 of Set 16 | simao
# Processing Record 14 of Set 16 | lac-megantic
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp          Current Description  \
# 0        Shihezi  44.3000   86.0333     35.04                    clear sky
# 1        Rikitea -23.1203 -134.9692     79.72                broken clouds
# 2       Buzmeyin  38.0507   58.2056     56.93  light intensity shower rain
# 3        Sambava -14.2667   50.1667     76.44                   light rain
# 4    Bandarbeyla   9.4942   50.8122     80.65                   few clouds
# 5          Kapaa  22.0752 -159.3190     80.92                   light rain
# 6  Ciudad Valles  21.9833  -99.0167     70.21                    clear sky
# 7       San Jose  37.3394 -121.8950     48.56                moderate rain
# 8          Sabha  27.0377   14.4283     64.47             scattered clouds
# 9         Bethel  41.3712  -73.4140     48.49                    clear sky
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        39           0        5.39      CN
# 1        77          65       15.10      PF
# 2        41         100        6.91      TM
# 3        86          98        5.70      MG
# 4        87          20        9.60      SO
# 5        75           0        5.75      US
# 6        78           0        4.18      MX
# 7        82         100       16.11      US
# 8        41          38       13.06      LY
# 9        49           0        0.00      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", 
                    "Current Description"] 


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
    

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Shihezi      CN  44.3000   86.0333     35.04        39           0
# 1        Rikitea      PF -23.1203 -134.9692     79.72        77          65
# 2       Buzmeyin      TM  38.0507   58.2056     56.93        41         100
# 3        Sambava      MG -14.2667   50.1667     76.44        86          98
# 4    Bandarbeyla      SO   9.4942   50.8122     80.65        87          20
# 5          Kapaa      US  22.0752 -159.3190     80.92        75           0
# 6  Ciudad Valles      MX  21.9833  -99.0167     70.21        78           0
# 7       San Jose      US  37.3394 -121.8950     48.56        82         100
# 8          Sabha      LY  27.0377   14.4283     64.47        41          38
# 9         Bethel      US  41.3712  -73.4140     48.49        49           0
#
#    Wind Speed          Current Description
# 0        5.39                    clear sky
# 1       15.10                broken clouds
# 2        6.91  light intensity shower rain
# 3        5.70                   light rain
# 4        9.60                   few clouds
# 5        5.75                   light rain
# 6        4.18                    clear sky
# 7       16.11                moderate rain
# 8       13.06             scattered clouds
# 9        0.00                    clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
